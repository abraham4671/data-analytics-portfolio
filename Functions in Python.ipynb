# %%
def bake_cake():
    print("cake is baking")

# %%
def water_plants():
    print("watering the plants")

# %%
def feed_cat():
    print("cat is eating")

feed_cat()
# Out:
# cat is eating

# %%
def paint_wall(color):
    print("painting with", color)

paint_wall("blue")
# Out:
# painting with blue

# %%
def make_tea(type):
    print("making", type, "tea")

make_tea("green")
# Out:
# making green tea

# %%
def add_stars(a, b):
    return a + b

result = add_stars(3, 4)
print(result)
# Out:
# 7

# %%
def check_ticket(number):
    print("checking ticket")
    return number

# %%
def build_house(rooms, style="modern"):
    print(style, rooms)

# %%
def mix_colors():
    shade = "purple"
    return shade

print(mix_colors())
# Out:
# purple
