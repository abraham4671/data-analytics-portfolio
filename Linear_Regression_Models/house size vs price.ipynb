# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# House size (in square feet)
X = np.array([500, 1000, 1500, 2000, 2500]).reshape(-1, 1)

# Price (in $1000s)
y = np.array([100, 150, 200, 250, 300])

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Slope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)
# Out:
# Slope (m): 0.10000000000000003
# Intercept (b): 49.99999999999994

# %%
# Predict price of a 1800 sq.ft. house
pred = model.predict([[1800]])
print("Predicted Price for 1800 sq.ft house:", pred[0])
# Out:
# Predicted Price for 1800 sq.ft house: 230.0

# %%
plt.scatter(X, y, color="blue", label="Actual Data")
plt.plot(X, model.predict(X), color="red", label="Best Fit Line")
plt.xlabel("House Size (sq.ft)")
plt.ylabel("Price ($1000s)")
plt.legend()
plt.show()
