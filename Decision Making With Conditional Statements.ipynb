# %%
x = 10
if x > 5
    print("x is greater than 5")

# %%
age = 18
if age >= 18
    print("you can vote")
else
    print("you cant vote")

# %%
marks = 75
if marks >= 90
    print("grade a")
elif marks >= 75
    print("grade b")
else
    print("grade c")

# %%
num = -5
if num < 0
    if num % 2 == 0
        print("negative even")
    else
        print("negative odd")

# %%
temp = 30
if temp > 20 and temp < 35
    print("weather is nice")
else
    print("weather is extreme")
