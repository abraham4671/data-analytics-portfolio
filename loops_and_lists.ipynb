# %%
numbers = [1, 2, 3, 4]

for n in numbers:
    print(n)
# Out:
# 1
# 2
# 3
# 4

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(6):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4
# 5

# %%
fruits = ["apple", "banana", "mango"]
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'orange']

# %%
colors = ["red", "blue", "green"]
colors.remove("blue")
print(colors)
# Out:
# ['red', 'green']

# %%
nums = [10, 20, 30]
print(nums[1])
# Out:
# 20

# %%
items = ["pen", "book", "eraser"]

for item in items:
    print(item)
# Out:
# pen
# book
# eraser

# %%
values = [1, 2, 3, 4, 5]
print(values[1:4])
# Out:
# [2, 3, 4]
